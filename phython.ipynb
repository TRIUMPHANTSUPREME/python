# %% [markdown]
# # MY JUPYTER NOTEBOOK ON IBM WATSON STUDIO

# %% [markdown]
# OGHOSASERE OSAYANDE
#
# A data scientist

# %% [markdown]
# I am interested in data science because it is a field that help us solve problems and make better decision with data, Plus it is the sexiest job in the planet.

# %% [markdown]
# ### WELCOME SALUTATION

# %%
x = input("name: ")
print("hello " + x)
# Out:
# name: ben
# hello ben

# %% [markdown]
# ![download%202.jpg](attachment:download%202.jpg)

# %% [markdown]
# ![download-1.jpg](attachment:download-1.jpg)

# %% [markdown]
# ![download-2.jpg](attachment:download-2.jpg)
